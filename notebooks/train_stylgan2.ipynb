# %% [markdown]
# # Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch")
import sys
sys.path.append('.')
# Out:
# Mounted at /content/drive

# %%
# !pip install ninja opensimplex torch==1.7.1 torchvision==0.8.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 108 kB 14.0 MB/s
# ...
#      |████████████████████████████████| 776.8 MB 17 kB/s
# ...
#      |████████████████████████████████| 12.8 MB 57.5 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.7.1 which is incompatible.
# ...

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Sep 11 19:44:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# %cd "/content/drive/MyDrive/repos/stylegan2-ada-pytorch"
base = "/content/drive/MyDrive"
file_name = "digital_art_f_256.zip"
src_dataset = f"{base}/data/datasets/{file_name}"
dataset = f"/content/{file_name}"
# %cp $src_dataset $dataset
outdir = f"{base}/data/training-runs/"
resume = f'{base}/data/nvidia-ada-models/ffhq256.pkl'
# Out:
# /content/drive/MyDrive/work/stylegan/extern/stylegan2-ada-pytorch

# %%
# %cd "/content/drive/MyDrive/repos/stylegan2-ada-pytorch"
base = "/content/drive/MyDrive"
dataset = f"{base}/data/datasets/digital_art_f_256.zip"
outdir = f"{base}/data/training-runs/"
resume = f'{base}/data/nvidia-ada-models/ffhq256.pkl'
# !python3 train.py --outdir=$outdir --data=$dataset --gpus=1 --cfg=paper256 --resume=$resume --snap=5 --nobench=True --workers=2
# Out:
# Aborted!
