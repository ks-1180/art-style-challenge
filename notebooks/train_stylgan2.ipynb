# %% [markdown]
# # Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch"
import sys
sys.path.append('.')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch

# %%
# !pip install ninja opensimplex torch==1.7.1 torchvision==0.8.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      |████████████████████████████████| 145 kB 33.8 MB/s
# Collecting opensimplex
#   Downloading opensimplex-0.4.3-py3-none-any.whl (19 kB)
# Collecting torch==1.7.1
#   Downloading torch-1.7.1-cp38-cp38-manylinux1_x86_64.whl (776.8 MB)
#      |████████████████████████████████| 776.8 MB 4.8 kB/s
# Collecting torchvision==0.8.2
#   Downloading torchvision-0.8.2-cp38-cp38-manylinux1_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 31.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.7.1) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torch==1.7.1) (1.21.6)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.8.2) (7.1.2)
# Collecting numpy
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 54.5 MB/s
# Installing collected packages: numpy, torch, torchvision, opensimplex, ninja
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.7.1 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.7.1 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.5 which is incompatible.
# Successfully installed ninja-1.11.1 numpy-1.23.5 opensimplex-0.4.3 torch-1.7.1 torchvision-0.8.2

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Dec  3 11:35:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
import os
torch.cuda.is_available()
# Out:
# True

# %%
os.path.exists('/content/drive/MyDrive/repos/art-style-challenge/data/training-runs/')
# Out:
# True

# %%
# %cd "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch"
base = "/content/drive/MyDrive/repos/art-style-challenge/data"
dataset = f"{base}/datasets/ghibli_male_256.zip"
outdir = f"{base}/training-runs/"
resume = '/content/drive/MyDrive/data/nvidia-ada-models/ffhq256.pkl'
# !python3 train.py --outdir=$outdir --data=$dataset --gpus=1 --cfg=paper256 --resume=$resume --snap=5 --nobench=True --workers=2
# Out:
# /content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 5,
#   "network_snapshot_ticks": 5,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/repos/art-style-challenge/data/datasets/ghibli_male_256.zip",
#     "use_labels": false,
#     "max_size": 1549,
#     "xflip": false,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 2,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 8
#     },
#     "channel_base": 16384,
#     "channel_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 1
#   },
#   "total_kimg": 25000,
#   "batch_size": 64,
#   "batch_gpu": 8,
#   "ema_kimg": 20,
#   "ema_rampup": null,
#   "ada_target": 0.6,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "resume_pkl": "/content/drive/MyDrive/data/nvidia-ada-models/ffhq256.pkl",
#   "ada_kimg": 100,
#   "cudnn_benchmark": false,
#   "run_dir": "/content/drive/MyDrive/repos/art-style-challenge/data/training-runs/00003-ghibli_male_256-paper256-resumecustom"
# }
#
# Output directory:   /content/drive/MyDrive/repos/art-style-challenge/data/training-runs/00003-ghibli_male_256-paper256-resumecustom
# Training data:      /content/drive/MyDrive/repos/art-style-challenge/data/datasets/ghibli_male_256.zip
# Training duration:  25000 kimg
# Number of GPUs:     1
# Number of images:   1549
# Image resolution:   256
# Conditional model:  False
# Dataset x-flips:    False
#
# Creating output directory...
# Launching processes...
# Loading training set...
#
# Num images:  1549
# Image shape: [3, 256, 256]
# Label shape: [0]
#
# Constructing networks...
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Resuming from "/content/drive/MyDrive/data/nvidia-ada-models/ffhq256.pkl"
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Generator             Parameters  Buffers  Output shape        Datatype
# ---                   ---         ---      ---                 ---
# mapping.fc0           262656      -        [8, 512]            float32
# mapping.fc1           262656      -        [8, 512]            float32
# mapping.fc2           262656      -        [8, 512]            float32
# mapping.fc3           262656      -        [8, 512]            float32
# mapping.fc4           262656      -        [8, 512]            float32
# mapping.fc5           262656      -        [8, 512]            float32
# mapping.fc6           262656      -        [8, 512]            float32
# mapping.fc7           262656      -        [8, 512]            float32
# mapping               -           512      [8, 14, 512]        float32
# synthesis.b4.conv1    2622465     32       [8, 512, 4, 4]      float32
# synthesis.b4.torgb    264195      -        [8, 3, 4, 4]        float32
# synthesis.b4:0        8192        16       [8, 512, 4, 4]      float32
# synthesis.b4:1        -           -        [8, 512, 4, 4]      float32
# synthesis.b8.conv0    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.conv1    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.torgb    264195      -        [8, 3, 8, 8]        float32
# synthesis.b8:0        -           16       [8, 512, 8, 8]      float32
# synthesis.b8:1        -           -        [8, 512, 8, 8]      float32
# synthesis.b16.conv0   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.conv1   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.torgb   264195      -        [8, 3, 16, 16]      float32
# synthesis.b16:0       -           16       [8, 512, 16, 16]    float32
# synthesis.b16:1       -           -        [8, 512, 16, 16]    float32
# synthesis.b32.conv0   2622465     1040     [8, 512, 32, 32]    float16
# synthesis.b32.conv1   2622465     1040     [8, 512, 32, 32]    float16
# synthesis.b32.torgb   264195      -        [8, 3, 32, 32]      float16
# synthesis.b32:0       -           16       [8, 512, 32, 32]    float16
# synthesis.b32:1       -           -        [8, 512, 32, 32]    float32
# synthesis.b64.conv0   1442561     4112     [8, 256, 64, 64]    float16
# synthesis.b64.conv1   721409      4112     [8, 256, 64, 64]    float16
# synthesis.b64.torgb   132099      -        [8, 3, 64, 64]      float16
# synthesis.b64:0       -           16       [8, 256, 64, 64]    float16
# synthesis.b64:1       -           -        [8, 256, 64, 64]    float32
# synthesis.b128.conv0  426369      16400    [8, 128, 128, 128]  float16
# synthesis.b128.conv1  213249      16400    [8, 128, 128, 128]  float16
# synthesis.b128.torgb  66051       -        [8, 3, 128, 128]    float16
# synthesis.b128:0      -           16       [8, 128, 128, 128]  float16
# synthesis.b128:1      -           -        [8, 128, 128, 128]  float32
# synthesis.b256.conv0  139457      65552    [8, 64, 256, 256]   float16
# synthesis.b256.conv1  69761       65552    [8, 64, 256, 256]   float16
# synthesis.b256.torgb  33027       -        [8, 3, 256, 256]    float16
# synthesis.b256:0      -           16       [8, 64, 256, 256]   float16
# synthesis.b256:1      -           -        [8, 64, 256, 256]   float32
# ---                   ---         ---      ---                 ---
# Total                 24767458    175568   -                   -
#
#
# Discriminator  Parameters  Buffers  Output shape        Datatype
# ---            ---         ---      ---                 ---
# b256.fromrgb   256         16       [8, 64, 256, 256]   float16
# b256.skip      8192        16       [8, 128, 128, 128]  float16
# b256.conv0     36928       16       [8, 64, 256, 256]   float16
# b256.conv1     73856       16       [8, 128, 128, 128]  float16
# b256           -           16       [8, 128, 128, 128]  float16
# b128.skip      32768       16       [8, 256, 64, 64]    float16
# b128.conv0     147584      16       [8, 128, 128, 128]  float16
# b128.conv1     295168      16       [8, 256, 64, 64]    float16
# b128           -           16       [8, 256, 64, 64]    float16
# b64.skip       131072      16       [8, 512, 32, 32]    float16
# b64.conv0      590080      16       [8, 256, 64, 64]    float16
# b64.conv1      1180160     16       [8, 512, 32, 32]    float16
# b64            -           16       [8, 512, 32, 32]    float16
# b32.skip       262144      16       [8, 512, 16, 16]    float16
# b32.conv0      2359808     16       [8, 512, 32, 32]    float16
# b32.conv1      2359808     16       [8, 512, 16, 16]    float16
# b32            -           16       [8, 512, 16, 16]    float16
# b16.skip       262144      16       [8, 512, 8, 8]      float32
# b16.conv0      2359808     16       [8, 512, 16, 16]    float32
# b16.conv1      2359808     16       [8, 512, 8, 8]      float32
# b16            -           16       [8, 512, 8, 8]      float32
# b8.skip        262144      16       [8, 512, 4, 4]      float32
# b8.conv0       2359808     16       [8, 512, 8, 8]      float32
# b8.conv1       2359808     16       [8, 512, 4, 4]      float32
# b8             -           16       [8, 512, 4, 4]      float32
# b4.mbstd       -           -        [8, 513, 4, 4]      float32
# b4.conv        2364416     16       [8, 512, 4, 4]      float32
# b4.fc          4194816     -        [8, 512]            float32
# b4.out         513         -        [8, 1]              float32
# ---            ---         ---      ---                 ---
# Total          24001089    416      -                   -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 0.1      time 1m 57s       sec/tick 10.4    sec/kimg 162.27  maintenance 106.6  cpumem 5.44   gpumem 2.73   augment 0.000
# Evaluating metrics...
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# {"results": {"fid50k_full": 248.63640453375206}, "metric": "fid50k_full", "total_time": 694.4049744606018, "total_time_str": "11m 34s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1670068181.6446588}
# tick 1     kimg 4.1      time 19m 36s      sec/tick 343.1   sec/kimg 85.09   maintenance 716.1  cpumem 5.64   gpumem 3.09   augment 0.031
# tick 2     kimg 8.1      time 25m 23s      sec/tick 347.1   sec/kimg 86.08   maintenance 0.0    cpumem 5.64   gpumem 3.09   augment 0.059
# tick 3     kimg 12.2     time 31m 10s      sec/tick 346.8   sec/kimg 86.01   maintenance 0.1    cpumem 5.64   gpumem 3.09   augment 0.095
# tick 4     kimg 16.2     time 36m 58s      sec/tick 347.6   sec/kimg 86.22   maintenance 0.1    cpumem 5.64   gpumem 3.09   augment 0.120
# tick 5     kimg 20.2     time 42m 44s      sec/tick 345.7   sec/kimg 85.73   maintenance 0.1    cpumem 5.64   gpumem 3.09   augment 0.151
# Evaluating metrics...
# {"results": {"fid50k_full": 188.66634462521483}, "metric": "fid50k_full", "total_time": 673.8990080356598, "total_time_str": "11m 14s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000020.pkl", "timestamp": 1670070607.635572}
# tick 6     kimg 24.3     time 1h 00m 04s   sec/tick 344.9   sec/kimg 85.53   maintenance 695.4  cpumem 5.63   gpumem 3.09   augment 0.184
# tick 7     kimg 28.3     time 1h 05m 50s   sec/tick 346.1   sec/kimg 85.83   maintenance 0.1    cpumem 5.63   gpumem 3.09   augment 0.200
# tick 8     kimg 32.3     time 1h 11m 36s   sec/tick 345.6   sec/kimg 85.72   maintenance 0.1    cpumem 5.63   gpumem 3.09   augment 0.215
# tick 9     kimg 36.4     time 1h 17m 20s   sec/tick 343.7   sec/kimg 85.25   maintenance 0.1    cpumem 5.63   gpumem 3.09   augment 0.236
# tick 10    kimg 40.4     time 1h 23m 05s   sec/tick 345.6   sec/kimg 85.73   maintenance 0.0    cpumem 5.63   gpumem 3.10   augment 0.243
# Evaluating metrics...
# {"results": {"fid50k_full": 90.34336143213692}, "metric": "fid50k_full", "total_time": 682.1136794090271, "total_time_str": "11m 22s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1670073035.3667977}
# tick 11    kimg 44.4     time 1h 40m 35s   sec/tick 348.5   sec/kimg 86.44   maintenance 701.5  cpumem 6.00   gpumem 3.11   augment 0.253
# tick 12    kimg 48.4     time 1h 46m 23s   sec/tick 347.8   sec/kimg 86.25   maintenance 0.1    cpumem 6.00   gpumem 3.10   augment 0.259
# tick 13    kimg 52.5     time 1h 52m 10s   sec/tick 346.2   sec/kimg 85.87   maintenance 0.1    cpumem 6.00   gpumem 3.10   augment 0.269
# tick 14    kimg 56.5     time 1h 57m 58s   sec/tick 348.2   sec/kimg 86.37   maintenance 0.0    cpumem 6.00   gpumem 3.10   augment 0.287
# tick 15    kimg 60.5     time 2h 03m 46s   sec/tick 348.2   sec/kimg 86.35   maintenance 0.1    cpumem 6.00   gpumem 3.11   augment 0.302
# Evaluating metrics...
# {"results": {"fid50k_full": 53.7024852456531}, "metric": "fid50k_full", "total_time": 678.2519006729126, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000060.pkl", "timestamp": 1670075471.1260889}
# tick 16    kimg 64.6     time 2h 21m 11s   sec/tick 348.4   sec/kimg 86.41   maintenance 696.5  cpumem 6.01   gpumem 3.10   augment 0.312
# tick 17    kimg 68.6     time 2h 26m 55s   sec/tick 344.3   sec/kimg 85.38   maintenance 0.1    cpumem 6.01   gpumem 3.13   augment 0.317
# tick 18    kimg 72.6     time 2h 32m 44s   sec/tick 348.2   sec/kimg 86.36   maintenance 0.0    cpumem 6.01   gpumem 3.10   augment 0.340
# tick 19    kimg 76.7     time 2h 38m 32s   sec/tick 348.2   sec/kimg 86.37   maintenance 0.1    cpumem 6.01   gpumem 3.11   augment 0.351
# tick 20    kimg 80.7     time 2h 44m 20s   sec/tick 348.0   sec/kimg 86.30   maintenance 0.1    cpumem 6.01   gpumem 3.10   augment 0.361
# Evaluating metrics...
# {"results": {"fid50k_full": 42.07034913917568}, "metric": "fid50k_full", "total_time": 678.1573042869568, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1670077904.8651721}
# tick 21    kimg 84.7     time 3h 01m 43s   sec/tick 346.7   sec/kimg 86.00   maintenance 696.4  cpumem 6.18   gpumem 3.10   augment 0.366
# tick 22    kimg 88.8     time 3h 07m 32s   sec/tick 348.6   sec/kimg 86.46   maintenance 0.0    cpumem 6.18   gpumem 3.10   augment 0.379
# tick 23    kimg 92.8     time 3h 13m 20s   sec/tick 348.5   sec/kimg 86.42   maintenance 0.1    cpumem 6.18   gpumem 3.11   augment 0.369
# tick 24    kimg 96.8     time 3h 19m 09s   sec/tick 348.2   sec/kimg 86.37   maintenance 0.1    cpumem 6.18   gpumem 3.13   augment 0.381
# tick 25    kimg 100.9    time 3h 24m 55s   sec/tick 346.3   sec/kimg 85.89   maintenance 0.1    cpumem 6.17   gpumem 3.12   augment 0.387
# Evaluating metrics...
# {"results": {"fid50k_full": 37.205053418438936}, "metric": "fid50k_full", "total_time": 677.3897800445557, "total_time_str": "11m 17s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000100.pkl", "timestamp": 1670080338.6216228}
# tick 26    kimg 104.9    time 3h 42m 19s   sec/tick 348.9   sec/kimg 86.53   maintenance 695.1  cpumem 6.08   gpumem 3.11   augment 0.379
# tick 27    kimg 108.9    time 3h 48m 08s   sec/tick 348.5   sec/kimg 86.44   maintenance 0.1    cpumem 6.08   gpumem 3.11   augment 0.394
# tick 28    kimg 113.0    time 3h 53m 56s   sec/tick 348.8   sec/kimg 86.50   maintenance 0.1    cpumem 6.08   gpumem 3.10   augment 0.404
# tick 29    kimg 117.0    time 3h 59m 43s   sec/tick 346.8   sec/kimg 86.00   maintenance 0.1    cpumem 6.07   gpumem 3.11   augment 0.389
# tick 30    kimg 121.0    time 4h 05m 32s   sec/tick 348.4   sec/kimg 86.41   maintenance 0.0    cpumem 6.07   gpumem 3.11   augment 0.392
# Evaluating metrics...
# {"results": {"fid50k_full": 33.92575502849344}, "metric": "fid50k_full", "total_time": 680.6405181884766, "total_time_str": "11m 21s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000121.pkl", "timestamp": 1670082778.8086793}
# tick 31    kimg 125.1    time 4h 22m 59s   sec/tick 348.5   sec/kimg 86.44   maintenance 698.5  cpumem 6.00   gpumem 3.11   augment 0.404
# tick 32    kimg 129.1    time 4h 28m 47s   sec/tick 348.4   sec/kimg 86.40   maintenance 0.1    cpumem 6.00   gpumem 3.11   augment 0.410
# tick 33    kimg 133.1    time 4h 34m 32s   sec/tick 344.5   sec/kimg 85.44   maintenance 0.1    cpumem 6.00   gpumem 3.11   augment 0.417
# tick 34    kimg 137.2    time 4h 40m 20s   sec/tick 348.5   sec/kimg 86.42   maintenance 0.0    cpumem 6.00   gpumem 3.10   augment 0.415
# tick 35    kimg 141.2    time 4h 46m 09s   sec/tick 348.3   sec/kimg 86.40   maintenance 0.1    cpumem 6.00   gpumem 3.10   augment 0.410
# Evaluating metrics...
# {"results": {"fid50k_full": 32.09126194090733}, "metric": "fid50k_full", "total_time": 681.827351808548, "total_time_str": "11m 22s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000141.pkl", "timestamp": 1670085216.8243175}
# tick 36    kimg 145.2    time 5h 03m 37s   sec/tick 348.7   sec/kimg 86.48   maintenance 699.5  cpumem 5.72   gpumem 3.12   augment 0.399
# tick 37    kimg 149.2    time 5h 09m 24s   sec/tick 346.9   sec/kimg 86.03   maintenance 0.1    cpumem 5.72   gpumem 3.13   augment 0.394
# tick 38    kimg 153.3    time 5h 15m 12s   sec/tick 348.5   sec/kimg 86.43   maintenance 0.0    cpumem 5.72   gpumem 3.11   augment 0.397
# tick 39    kimg 157.3    time 5h 21m 01s   sec/tick 348.7   sec/kimg 86.49   maintenance 0.1    cpumem 5.72   gpumem 3.10   augment 0.397
# tick 40    kimg 161.3    time 5h 26m 50s   sec/tick 348.6   sec/kimg 86.46   maintenance 0.1    cpumem 5.72   gpumem 3.12   augment 0.417
# Evaluating metrics...
# {"results": {"fid50k_full": 30.06256593999941}, "metric": "fid50k_full", "total_time": 678.4575338363647, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000161.pkl", "timestamp": 1670087655.0138457}
# tick 41    kimg 165.4    time 5h 44m 14s   sec/tick 347.3   sec/kimg 86.14   maintenance 696.5  cpumem 5.98   gpumem 3.12   augment 0.407
# tick 42    kimg 169.4    time 5h 50m 02s   sec/tick 348.1   sec/kimg 86.34   maintenance 0.0    cpumem 5.98   gpumem 3.11   augment 0.415
# tick 43    kimg 173.4    time 5h 55m 51s   sec/tick 348.8   sec/kimg 86.50   maintenance 0.1    cpumem 5.98   gpumem 3.12   augment 0.417
# tick 44    kimg 177.5    time 6h 01m 40s   sec/tick 348.7   sec/kimg 86.47   maintenance 0.1    cpumem 5.98   gpumem 3.11   augment 0.422
# tick 45    kimg 181.5    time 6h 07m 25s   sec/tick 345.3   sec/kimg 85.64   maintenance 0.1    cpumem 5.97   gpumem 3.11   augment 0.422
# Evaluating metrics...
# {"results": {"fid50k_full": 29.32815758072286}, "metric": "fid50k_full", "total_time": 680.3851144313812, "total_time_str": "11m 20s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000181.pkl", "timestamp": 1670090091.9252987}
# tick 46    kimg 185.5    time 6h 24m 52s   sec/tick 348.9   sec/kimg 86.53   maintenance 698.4  cpumem 5.93   gpumem 3.11   augment 0.425
# tick 47    kimg 189.6    time 6h 30m 41s   sec/tick 349.1   sec/kimg 86.59   maintenance 0.1    cpumem 5.93   gpumem 3.11   augment 0.430
# tick 48    kimg 193.6    time 6h 36m 30s   sec/tick 348.9   sec/kimg 86.53   maintenance 0.1    cpumem 5.93   gpumem 3.10   augment 0.430
# tick 49    kimg 197.6    time 6h 42m 15s   sec/tick 344.9   sec/kimg 85.54   maintenance 0.1    cpumem 5.93   gpumem 3.12   augment 0.425
# tick 50    kimg 201.7    time 6h 48m 04s   sec/tick 348.8   sec/kimg 86.50   maintenance 0.0    cpumem 5.93   gpumem 3.11   augment 0.433
# Evaluating metrics...
# {"results": {"fid50k_full": 28.133356266150308}, "metric": "fid50k_full", "total_time": 679.5429682731628, "total_time_str": "11m 20s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000201.pkl", "timestamp": 1670092530.8498874}
# tick 51    kimg 205.7    time 7h 05m 31s   sec/tick 349.1   sec/kimg 86.59   maintenance 698.0  cpumem 5.96   gpumem 3.11   augment 0.428
# tick 52    kimg 209.7    time 7h 11m 20s   sec/tick 348.6   sec/kimg 86.45   maintenance 0.1    cpumem 5.96   gpumem 3.13   augment 0.428
# tick 53    kimg 213.8    time 7h 17m 07s   sec/tick 346.9   sec/kimg 86.03   maintenance 0.1    cpumem 5.96   gpumem 3.12   augment 0.438
# tick 54    kimg 217.8    time 7h 22m 56s   sec/tick 348.7   sec/kimg 86.49   maintenance 0.0    cpumem 5.96   gpumem 3.11   augment 0.435
# tick 55    kimg 221.8    time 7h 28m 44s   sec/tick 348.4   sec/kimg 86.41   maintenance 0.1    cpumem 5.96   gpumem 3.11   augment 0.440
# Evaluating metrics...
# {"results": {"fid50k_full": 27.36704517601385}, "metric": "fid50k_full", "total_time": 678.8197720050812, "total_time_str": "11m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000221.pkl", "timestamp": 1670094970.0460231}
# tick 56    kimg 225.9    time 7h 46m 10s   sec/tick 348.6   sec/kimg 86.45   maintenance 697.1  cpumem 6.02   gpumem 3.11   augment 0.440
# tick 57    kimg 229.9    time 7h 51m 57s   sec/tick 346.6   sec/kimg 85.95   maintenance 0.1    cpumem 6.02   gpumem 3.12   augment 0.440
# tick 58    kimg 233.9    time 7h 57m 45s   sec/tick 348.4   sec/kimg 86.40   maintenance 0.0    cpumem 6.02   gpumem 3.11   augment 0.443
# tick 59    kimg 238.0    time 8h 03m 34s   sec/tick 348.6   sec/kimg 86.45   maintenance 0.1    cpumem 6.02   gpumem 3.11   augment 0.443
# tick 60    kimg 242.0    time 8h 09m 22s   sec/tick 348.6   sec/kimg 86.46   maintenance 0.1    cpumem 6.02   gpumem 3.11   augment 0.448
# Evaluating metrics...
# {"results": {"fid50k_full": 27.300395242397233}, "metric": "fid50k_full", "total_time": 686.4963533878326, "total_time_str": "11m 26s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000241.pkl", "timestamp": 1670097415.2081637}
# tick 61    kimg 246.0    time 8h 26m 54s   sec/tick 346.9   sec/kimg 86.05   maintenance 704.2  cpumem 5.75   gpumem 3.12   augment 0.458
# tick 62    kimg 250.0    time 8h 32m 42s   sec/tick 348.7   sec/kimg 86.48   maintenance 0.0    cpumem 5.75   gpumem 3.11   augment 0.456
# tick 63    kimg 254.1    time 8h 38m 31s   sec/tick 348.7   sec/kimg 86.48   maintenance 0.1    cpumem 5.75   gpumem 3.12   augment 0.461
# tick 64    kimg 258.1    time 8h 44m 20s   sec/tick 348.9   sec/kimg 86.53   maintenance 0.1    cpumem 5.75   gpumem 3.12   augment 0.471
# tick 65    kimg 262.1    time 8h 50m 05s   sec/tick 344.4   sec/kimg 85.42   maintenance 0.1    cpumem 5.75   gpumem 3.12   augment 0.471
# Evaluating metrics...
# {"results": {"fid50k_full": 26.461680258411967}, "metric": "fid50k_full", "total_time": 685.767627954483, "total_time_str": "11m 26s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000262.pkl", "timestamp": 1670099856.8065228}
# tick 66    kimg 266.2    time 9h 07m 37s   sec/tick 348.8   sec/kimg 86.51   maintenance 703.7  cpumem 5.88   gpumem 3.12   augment 0.468
# tick 67    kimg 270.2    time 9h 13m 26s   sec/tick 348.5   sec/kimg 86.43   maintenance 0.1    cpumem 5.88   gpumem 3.11   augment 0.463
# tick 68    kimg 274.2    time 9h 19m 14s   sec/tick 348.8   sec/kimg 86.50   maintenance 0.1    cpumem 5.88   gpumem 3.13   augment 0.448
# tick 69    kimg 278.3    time 9h 25m 01s   sec/tick 346.6   sec/kimg 85.97   maintenance 0.1    cpumem 5.88   gpumem 3.12   augment 0.463
# tick 70    kimg 282.3    time 9h 30m 49s   sec/tick 348.2   sec/kimg 86.36   maintenance 0.0    cpumem 5.88   gpumem 3.13   augment 0.466
# Evaluating metrics...
# {"results": {"fid50k_full": 25.74890787907007}, "metric": "fid50k_full", "total_time": 678.2670223712921, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000282.pkl", "timestamp": 1670102294.9934602}
# tick 71    kimg 286.3    time 9h 48m 15s   sec/tick 349.0   sec/kimg 86.55   maintenance 697.0  cpumem 5.92   gpumem 3.11   augment 0.466
# tick 72    kimg 290.4    time 9h 54m 04s   sec/tick 348.7   sec/kimg 86.48   maintenance 0.1    cpumem 5.91   gpumem 3.11   augment 0.481
# tick 73    kimg 294.4    time 9h 59m 51s   sec/tick 347.0   sec/kimg 86.06   maintenance 0.1    cpumem 5.91   gpumem 3.11   augment 0.481
# tick 74    kimg 298.4    time 10h 05m 40s  sec/tick 348.7   sec/kimg 86.47   maintenance 0.0    cpumem 5.90   gpumem 3.14   augment 0.479
# tick 75    kimg 302.5    time 10h 11m 29s  sec/tick 348.9   sec/kimg 86.53   maintenance 0.1    cpumem 5.89   gpumem 3.12   augment 0.476
# Evaluating metrics...
# {"results": {"fid50k_full": 25.287600406780903}, "metric": "fid50k_full", "total_time": 676.5844466686249, "total_time_str": "11m 17s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000302.pkl", "timestamp": 1670104732.0480325}
# tick 76    kimg 306.5    time 10h 28m 52s  sec/tick 348.9   sec/kimg 86.54   maintenance 694.5  cpumem 5.98   gpumem 3.11   augment 0.481
# tick 77    kimg 310.5    time 10h 34m 39s  sec/tick 346.9   sec/kimg 86.03   maintenance 0.1    cpumem 5.98   gpumem 3.12   augment 0.492
# tick 78    kimg 314.6    time 10h 40m 28s  sec/tick 349.0   sec/kimg 86.56   maintenance 0.0    cpumem 5.98   gpumem 3.13   augment 0.484
# tick 79    kimg 318.6    time 10h 46m 17s  sec/tick 348.8   sec/kimg 86.51   maintenance 0.1    cpumem 5.97   gpumem 3.11   augment 0.486
# tick 80    kimg 322.6    time 10h 52m 06s  sec/tick 348.8   sec/kimg 86.50   maintenance 0.1    cpumem 5.96   gpumem 3.12   augment 0.471
# Evaluating metrics...
# {"results": {"fid50k_full": 25.20647267114805}, "metric": "fid50k_full", "total_time": 678.1230273246765, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000322.pkl", "timestamp": 1670107170.9729526}
# tick 81    kimg 326.7    time 11h 09m 28s  sec/tick 345.2   sec/kimg 85.62   maintenance 696.2  cpumem 5.90   gpumem 3.13   augment 0.476
# tick 82    kimg 330.7    time 11h 15m 17s  sec/tick 348.9   sec/kimg 86.54   maintenance 0.0    cpumem 5.90   gpumem 3.15   augment 0.474
# tick 83    kimg 334.7    time 11h 21m 05s  sec/tick 348.1   sec/kimg 86.32   maintenance 0.1    cpumem 5.90   gpumem 3.11   augment 0.484
# tick 84    kimg 338.8    time 11h 26m 54s  sec/tick 349.1   sec/kimg 86.57   maintenance 0.1    cpumem 5.90   gpumem 3.12   augment 0.494
# tick 85    kimg 342.8    time 11h 32m 41s  sec/tick 347.1   sec/kimg 86.08   maintenance 0.1    cpumem 5.90   gpumem 3.12   augment 0.499
# Evaluating metrics...
# {"results": {"fid50k_full": 25.58361209137106}, "metric": "fid50k_full", "total_time": 678.7579660415649, "total_time_str": "11m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000342.pkl", "timestamp": 1670109606.421922}
# tick 86    kimg 346.8    time 11h 50m 07s  sec/tick 348.9   sec/kimg 86.54   maintenance 696.8  cpumem 5.83   gpumem 3.12   augment 0.486
# tick 87    kimg 350.8    time 11h 55m 56s  sec/tick 349.0   sec/kimg 86.56   maintenance 0.1    cpumem 5.83   gpumem 3.12   augment 0.492
# tick 88    kimg 354.9    time 12h 01m 45s  sec/tick 349.0   sec/kimg 86.56   maintenance 0.1    cpumem 5.83   gpumem 3.12   augment 0.502
# tick 89    kimg 358.9    time 12h 07m 32s  sec/tick 347.2   sec/kimg 86.11   maintenance 0.1    cpumem 5.83   gpumem 3.11   augment 0.502
# tick 90    kimg 362.9    time 12h 13m 21s  sec/tick 348.6   sec/kimg 86.46   maintenance 0.0    cpumem 5.83   gpumem 3.14   augment 0.509
# Evaluating metrics...
# {"results": {"fid50k_full": 24.88724829219673}, "metric": "fid50k_full", "total_time": 677.785078048706, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000362.pkl", "timestamp": 1670112045.4759667}
# tick 91    kimg 367.0    time 12h 30m 46s  sec/tick 349.1   sec/kimg 86.59   maintenance 695.9  cpumem 5.98   gpumem 3.12   augment 0.504
# tick 92    kimg 371.0    time 12h 36m 35s  sec/tick 349.0   sec/kimg 86.55   maintenance 0.1    cpumem 5.98   gpumem 3.12   augment 0.515
# tick 93    kimg 375.0    time 12h 42m 22s  sec/tick 347.1   sec/kimg 86.09   maintenance 0.1    cpumem 5.98   gpumem 3.11   augment 0.499
# tick 94    kimg 379.1    time 12h 48m 10s  sec/tick 347.6   sec/kimg 86.21   maintenance 0.0    cpumem 5.96   gpumem 3.13   augment 0.492
# tick 95    kimg 383.1    time 12h 53m 59s  sec/tick 348.6   sec/kimg 86.46   maintenance 0.1    cpumem 5.96   gpumem 3.12   augment 0.486
# Evaluating metrics...
# {"results": {"fid50k_full": 24.10311291984199}, "metric": "fid50k_full", "total_time": 677.5860216617584, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000383.pkl", "timestamp": 1670114483.0388448}
# tick 96    kimg 387.1    time 13h 11m 24s  sec/tick 349.1   sec/kimg 86.58   maintenance 695.8  cpumem 5.94   gpumem 3.13   augment 0.481
# tick 97    kimg 391.2    time 13h 17m 08s  sec/tick 344.8   sec/kimg 85.50   maintenance 0.1    cpumem 5.94   gpumem 3.13   augment 0.476
# tick 98    kimg 395.2    time 13h 22m 58s  sec/tick 349.3   sec/kimg 86.62   maintenance 0.0    cpumem 5.94   gpumem 3.12   augment 0.479
# tick 99    kimg 399.2    time 13h 28m 46s  sec/tick 348.5   sec/kimg 86.43   maintenance 0.1    cpumem 5.94   gpumem 3.11   augment 0.468
# tick 100   kimg 403.3    time 13h 34m 35s  sec/tick 349.1   sec/kimg 86.59   maintenance 0.1    cpumem 5.94   gpumem 3.14   augment 0.458
# Evaluating metrics...
# {"results": {"fid50k_full": 24.240328535270166}, "metric": "fid50k_full", "total_time": 676.1561250686646, "total_time_str": "11m 16s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000403.pkl", "timestamp": 1670116918.3742123}
# tick 101   kimg 407.3    time 13h 51m 55s  sec/tick 345.4   sec/kimg 85.66   maintenance 694.3  cpumem 5.88   gpumem 3.13   augment 0.463
# tick 102   kimg 411.3    time 13h 57m 43s  sec/tick 347.6   sec/kimg 86.21   maintenance 0.0    cpumem 5.88   gpumem 3.13   augment 0.481
# tick 103   kimg 415.4    time 14h 03m 31s  sec/tick 348.6   sec/kimg 86.46   maintenance 0.1    cpumem 5.88   gpumem 3.11   augment 0.481
# tick 104   kimg 419.4    time 14h 09m 20s  sec/tick 348.6   sec/kimg 86.45   maintenance 0.1    cpumem 5.88   gpumem 3.14   augment 0.476
# tick 105   kimg 423.4    time 14h 15m 06s  sec/tick 346.0   sec/kimg 85.81   maintenance 0.1    cpumem 5.88   gpumem 3.12   augment 0.476
# Evaluating metrics...
# {"results": {"fid50k_full": 24.39599183864532}, "metric": "fid50k_full", "total_time": 679.4905886650085, "total_time_str": "11m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000423.pkl", "timestamp": 1670119352.1727638}
# tick 106   kimg 427.5    time 14h 32m 32s  sec/tick 348.8   sec/kimg 86.51   maintenance 697.3  cpumem 5.92   gpumem 3.12   augment 0.494
# tick 107   kimg 431.5    time 14h 38m 21s  sec/tick 348.7   sec/kimg 86.47   maintenance 0.1    cpumem 5.92   gpumem 3.12   augment 0.494
# tick 108   kimg 435.5    time 14h 44m 10s  sec/tick 348.4   sec/kimg 86.42   maintenance 0.1    cpumem 5.92   gpumem 3.13   augment 0.489
# tick 109   kimg 439.6    time 14h 49m 57s  sec/tick 347.0   sec/kimg 86.07   maintenance 0.1    cpumem 5.92   gpumem 3.12   augment 0.489
# tick 110   kimg 443.6    time 14h 55m 46s  sec/tick 348.9   sec/kimg 86.54   maintenance 0.0    cpumem 5.92   gpumem 3.12   augment 0.497
# Evaluating metrics...
# {"results": {"fid50k_full": 24.449115848944693}, "metric": "fid50k_full", "total_time": 681.5489265918732, "total_time_str": "11m 22s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000443.pkl", "timestamp": 1670121793.815734}
# tick 111   kimg 447.6    time 15h 13m 14s  sec/tick 349.2   sec/kimg 86.61   maintenance 699.4  cpumem 5.82   gpumem 3.12   augment 0.507
# tick 112   kimg 451.6    time 15h 19m 03s  sec/tick 348.9   sec/kimg 86.53   maintenance 0.1    cpumem 5.82   gpumem 3.12   augment 0.497
# tick 113   kimg 455.7    time 15h 24m 48s  sec/tick 344.2   sec/kimg 85.37   maintenance 0.1    cpumem 5.82   gpumem 3.11   augment 0.502
# tick 114   kimg 459.7    time 15h 30m 35s  sec/tick 347.0   sec/kimg 86.07   maintenance 0.0    cpumem 5.82   gpumem 3.13   augment 0.494
# tick 115   kimg 463.7    time 15h 36m 22s  sec/tick 347.0   sec/kimg 86.06   maintenance 0.1    cpumem 5.82   gpumem 3.13   augment 0.499
# Evaluating metrics...
# {"results": {"fid50k_full": 24.61045524690814}, "metric": "fid50k_full", "total_time": 673.8307583332062, "total_time_str": "11m 14s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000463.pkl", "timestamp": 1670124222.3337982}
# tick 116   kimg 467.8    time 15h 53m 39s  sec/tick 345.5   sec/kimg 85.69   maintenance 691.8  cpumem 6.00   gpumem 3.12   augment 0.504
# tick 117   kimg 471.8    time 15h 59m 24s  sec/tick 344.9   sec/kimg 85.55   maintenance 0.1    cpumem 6.00   gpumem 3.14   augment 0.499
# tick 118   kimg 475.8    time 16h 05m 11s  sec/tick 346.5   sec/kimg 85.94   maintenance 0.0    cpumem 5.99   gpumem 3.12   augment 0.497
# tick 119   kimg 479.9    time 16h 10m 57s  sec/tick 346.4   sec/kimg 85.92   maintenance 0.1    cpumem 5.99   gpumem 3.11   augment 0.512
# tick 120   kimg 483.9    time 16h 16m 44s  sec/tick 346.7   sec/kimg 85.99   maintenance 0.1    cpumem 5.99   gpumem 3.12   augment 0.512
# Evaluating metrics...
# {"results": {"fid50k_full": 24.32858529850717}, "metric": "fid50k_full", "total_time": 678.1613657474518, "total_time_str": "11m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000483.pkl", "timestamp": 1670126648.7648377}
# tick 121   kimg 487.9    time 16h 34m 04s  sec/tick 343.7   sec/kimg 85.24   maintenance 696.0  cpumem 5.91   gpumem 3.13   augment 0.512
# tick 122   kimg 492.0    time 16h 39m 51s  sec/tick 346.7   sec/kimg 85.99   maintenance 0.0    cpumem 5.91   gpumem 3.11   augment 0.507
# tick 123   kimg 496.0    time 16h 45m 37s  sec/tick 346.6   sec/kimg 85.96   maintenance 0.1    cpumem 5.91   gpumem 3.13   augment 0.507
# tick 124   kimg 500.0    time 16h 51m 24s  sec/tick 346.7   sec/kimg 86.00   maintenance 0.1    cpumem 5.91   gpumem 3.13   augment 0.497
# tick 125   kimg 504.1    time 16h 57m 09s  sec/tick 344.9   sec/kimg 85.53   maintenance 0.1    cpumem 5.91   gpumem 3.13   augment 0.502
# Evaluating metrics...
# {"results": {"fid50k_full": 24.143633821102803}, "metric": "fid50k_full", "total_time": 679.808431148529, "total_time_str": "11m 20s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000504.pkl", "timestamp": 1670129075.1754124}
# tick 126   kimg 508.1    time 17h 14m 32s  sec/tick 345.7   sec/kimg 85.73   maintenance 697.5  cpumem 5.88   gpumem 3.11   augment 0.509
# tick 127   kimg 512.1    time 17h 20m 19s  sec/tick 346.8   sec/kimg 86.01   maintenance 0.1    cpumem 5.88   gpumem 3.13   augment 0.515
# tick 128   kimg 516.2    time 17h 26m 06s  sec/tick 346.8   sec/kimg 86.01   maintenance 0.1    cpumem 5.88   gpumem 3.12   augment 0.515
# tick 129   kimg 520.2    time 17h 31m 49s  sec/tick 342.8   sec/kimg 85.03   maintenance 0.1    cpumem 5.88   gpumem 3.12   augment 0.520
# tick 130   kimg 524.2    time 17h 37m 36s  sec/tick 346.5   sec/kimg 85.95   maintenance 0.0    cpumem 5.88   gpumem 3.13   augment 0.522
# Evaluating metrics...
# {"results": {"fid50k_full": 23.675431123468513}, "metric": "fid50k_full", "total_time": 680.679779291153, "total_time_str": "11m 21s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000524.pkl", "timestamp": 1670131502.766385}
# tick 131   kimg 528.3    time 17h 55m 00s  sec/tick 345.5   sec/kimg 85.70   maintenance 698.6  cpumem 5.94   gpumem 3.14   augment 0.512
# tick 132   kimg 532.3    time 18h 00m 46s  sec/tick 346.6   sec/kimg 85.96   maintenance 0.1    cpumem 5.94   gpumem 3.11   augment 0.517
# tick 133   kimg 536.3    time 18h 06m 32s  sec/tick 345.0   sec/kimg 85.58   maintenance 0.1    cpumem 5.94   gpumem 3.13   augment 0.517
# tick 134   kimg 540.4    time 18h 12m 18s  sec/tick 346.7   sec/kimg 85.99   maintenance 0.0    cpumem 5.94   gpumem 3.12   augment 0.509
# tick 135   kimg 544.4    time 18h 18m 05s  sec/tick 346.6   sec/kimg 85.96   maintenance 0.1    cpumem 5.94   gpumem 3.12   augment 0.509
# Evaluating metrics...
# {"results": {"fid50k_full": 23.545154042489322}, "metric": "fid50k_full", "total_time": 672.5224661827087, "total_time_str": "11m 13s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000544.pkl", "timestamp": 1670133924.083628}
# tick 136   kimg 548.4    time 18h 35m 21s  sec/tick 345.5   sec/kimg 85.69   maintenance 690.5  cpumem 5.89   gpumem 3.13   augment 0.509
# tick 137   kimg 552.4    time 18h 41m 06s  sec/tick 344.8   sec/kimg 85.52   maintenance 0.1    cpumem 5.89   gpumem 3.12   augment 0.504
# tick 138   kimg 556.5    time 18h 46m 53s  sec/tick 346.8   sec/kimg 86.01   maintenance 0.0    cpumem 5.89   gpumem 3.11   augment 0.502
# tick 139   kimg 560.5    time 18h 52m 40s  sec/tick 347.0   sec/kimg 86.05   maintenance 0.1    cpumem 5.89   gpumem 3.15   augment 0.517
# tick 140   kimg 564.5    time 18h 58m 27s  sec/tick 346.8   sec/kimg 86.02   maintenance 0.1    cpumem 5.89   gpumem 3.13   augment 0.517
# Evaluating metrics...
# {"results": {"fid50k_full": 23.40756779873559}, "metric": "fid50k_full", "total_time": 679.5754010677338, "total_time_str": "11m 20s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000564.pkl", "timestamp": 1670136352.9147263}
# tick 141   kimg 568.6    time 19h 15m 51s  sec/tick 347.1   sec/kimg 86.10   maintenance 697.7  cpumem 5.90   gpumem 3.14   augment 0.502
# tick 142   kimg 572.6    time 19h 21m 40s  sec/tick 348.9   sec/kimg 86.53   maintenance 0.0    cpumem 5.90   gpumem 3.13   augment 0.504
# tick 143   kimg 576.6    time 19h 27m 29s  sec/tick 348.8   sec/kimg 86.51   maintenance 0.1    cpumem 5.90   gpumem 3.12   augment 0.509
# tick 144   kimg 580.7    time 19h 33m 18s  sec/tick 348.5   sec/kimg 86.44   maintenance 0.1    cpumem 5.90   gpumem 3.13   augment 0.515
# tick 145   kimg 584.7    time 19h 39m 03s  sec/tick 344.9   sec/kimg 85.53   maintenance 0.1    cpumem 5.90   gpumem 3.12   augment 0.515
# Evaluating metrics...
# {"results": {"fid50k_full": 23.29271132861852}, "metric": "fid50k_full", "total_time": 678.7199196815491, "total_time_str": "11m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000584.pkl", "timestamp": 1670138788.1867957}
# tick 146   kimg 588.7    time 19h 56m 29s  sec/tick 349.2   sec/kimg 86.61   maintenance 696.7  cpumem 5.88   gpumem 3.12   augment 0.517
# tick 147   kimg 592.8    time 20h 02m 17s  sec/tick 348.6   sec/kimg 86.45   maintenance 0.1    cpumem 5.87   gpumem 3.14   augment 0.527
# tick 148   kimg 596.8    time 20h 08m 06s  sec/tick 348.6   sec/kimg 86.46   maintenance 0.1    cpumem 5.87   gpumem 3.12   augment 0.527
# tick 149   kimg 600.8    time 20h 13m 53s  sec/tick 347.0   sec/kimg 86.06   maintenance 0.1    cpumem 5.87   gpumem 3.12   augment 0.522
# tick 150   kimg 604.9    time 20h 19m 42s  sec/tick 348.8   sec/kimg 86.51   maintenance 0.0    cpumem 5.87   gpumem 3.15   augment 0.520
# Evaluating metrics...
# {"results": {"fid50k_full": 23.246196334864308}, "metric": "fid50k_full", "total_time": 684.8258373737335, "total_time_str": "11m 25s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000604.pkl", "timestamp": 1670141233.808905}
# tick 151   kimg 608.9    time 20h 37m 14s  sec/tick 349.0   sec/kimg 86.56   maintenance 703.1  cpumem 5.86   gpumem 3.12   augment 0.520
# tick 152   kimg 612.9    time 20h 43m 03s  sec/tick 348.7   sec/kimg 86.48   maintenance 0.1    cpumem 5.86   gpumem 3.12   augment 0.517
# tick 153   kimg 617.0    time 20h 48m 50s  sec/tick 346.6   sec/kimg 85.96   maintenance 0.1    cpumem 5.86   gpumem 3.14   augment 0.517
# tick 154   kimg 621.0    time 20h 54m 38s  sec/tick 348.6   sec/kimg 86.45   maintenance 0.0    cpumem 5.86   gpumem 3.13   augment 0.515
# tick 155   kimg 625.0    time 21h 00m 27s  sec/tick 348.8   sec/kimg 86.51   maintenance 0.1    cpumem 5.86   gpumem 3.12   augment 0.525
# Evaluating metrics...
# {"results": {"fid50k_full": 23.459560028930497}, "metric": "fid50k_full", "total_time": 678.9962406158447, "total_time_str": "11m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000625.pkl", "timestamp": 1670143672.7539067}
# tick 156   kimg 629.1    time 21h 17m 53s  sec/tick 349.3   sec/kimg 86.64   maintenance 697.0  cpumem 5.88   gpumem 3.12   augment 0.535
# tick 157   kimg 633.1    time 21h 23m 41s  sec/tick 347.2   sec/kimg 86.11   maintenance 0.1    cpumem 5.88   gpumem 3.14   augment 0.535
# tick 158   kimg 637.1    time 21h 29m 30s  sec/tick 348.9   sec/kimg 86.52   maintenance 0.0    cpumem 5.88   gpumem 3.13   augment 0.527
# tick 159   kimg 641.2    time 21h 35m 18s  sec/tick 348.7   sec/kimg 86.48   maintenance 0.1    cpumem 5.88   gpumem 3.12   augment 0.517
# tick 160   kimg 645.2    time 21h 41m 07s  sec/tick 348.6   sec/kimg 86.45   maintenance 0.1    cpumem 5.88   gpumem 3.13   augment 0.527
# Evaluating metrics...
# {"results": {"fid50k_full": 22.820859471757707}, "metric": "fid50k_full", "total_time": 687.072562456131, "total_time_str": "11m 27s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000645.pkl", "timestamp": 1670146120.8917146}
# tick 161   kimg 649.2    time 21h 58m 37s  sec/tick 345.0   sec/kimg 85.56   maintenance 705.2  cpumem 5.85   gpumem 3.12   augment 0.522
# tick 162   kimg 653.2    time 22h 04m 26s  sec/tick 348.6   sec/kimg 86.45   maintenance 0.0    cpumem 5.85   gpumem 3.13   augment 0.525
# tick 163   kimg 657.3    time 22h 10m 15s  sec/tick 349.2   sec/kimg 86.60   maintenance 0.1    cpumem 5.85   gpumem 3.13   augment 0.530
# tick 164   kimg 661.3    time 22h 16m 04s  sec/tick 348.8   sec/kimg 86.50   maintenance 0.1    cpumem 5.85   gpumem 3.13   augment 0.520
# tick 165   kimg 665.3    time 22h 21m 51s  sec/tick 346.9   sec/kimg 86.04   maintenance 0.1    cpumem 5.85   gpumem 3.13   augment 0.504
# Evaluating metrics...
# {"results": {"fid50k_full": 23.145290469853823}, "metric": "fid50k_full", "total_time": 679.172116279602, "total_time_str": "11m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000665.pkl", "timestamp": 1670148556.7104728}
# tick 166   kimg 669.4    time 22h 39m 17s  sec/tick 349.1   sec/kimg 86.58   maintenance 697.1  cpumem 5.85   gpumem 3.13   augment 0.517
# tick 167   kimg 673.4    time 22h 45m 07s  sec/tick 349.3   sec/kimg 86.63   maintenance 0.1    cpumem 5.85   gpumem 3.13   augment 0.522
# tick 168   kimg 677.4    time 22h 50m 56s  sec/tick 349.2   sec/kimg 86.61   maintenance 0.1    cpumem 5.84   gpumem 3.12   augment 0.538
# tick 169   kimg 681.5    time 22h 56m 43s  sec/tick 347.0   sec/kimg 86.06   maintenance 0.1    cpumem 5.84   gpumem 3.13   augment 0.543
# tick 170   kimg 685.5    time 23h 02m 32s  sec/tick 348.7   sec/kimg 86.49   maintenance 0.0    cpumem 5.84   gpumem 3.13   augment 0.553
# Evaluating metrics...
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 610, in invoke
#     return callback(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/click/decorators.py", line 21, in new_func
#     return f(get_current_context(), *args, **kwargs)
#   File "train.py", line 531, in main
#     subprocess_fn(rank=0, args=args, temp_dir=temp_dir)
#   File "train.py", line 383, in subprocess_fn
#     training_loop.training_loop(rank=rank, **args)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/training/training_loop.py", line 374, in training_loop
#     result_dict = metric_main.calc_metric(metric=metric, G=snapshot_data['G_ema'],
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/metrics/metric_main.py", line 45, in calc_metric
#     results = _metric_dict[metric](opts)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/metrics/metric_main.py", line 85, in fid50k_full
#     fid = frechet_inception_distance.compute_fid(opts, max_real=None, num_gen=50000)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/metrics/frechet_inception_distance.py", line 29, in compute_fid
#     mu_gen, sigma_gen = metric_utils.compute_feature_stats_for_generator(
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/metrics/metric_utils.py", line 266, in compute_feature_stats_for_generator
#     images.append(run_generator(z, c))
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/metrics/metric_utils.py", line 243, in run_generator
#     img = G(z=z, c=c, **opts.G_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/training/networks.py", line 499, in forward
#     img = self.synthesis(ws, **synthesis_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/training/networks.py", line 471, in forward
#     x, img = block(x, img, cur_ws, **block_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/training/networks.py", line 406, in forward
#     x = self.conv1(x, next(w_iter), fused_modconv=fused_modconv, **layer_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/training/networks.py", line 299, in forward
#     x = modulated_conv2d(x=x, weight=self.weight, styles=styles, noise=noise, up=self.up,
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/torch_utils/misc.py", line 101, in decorator
#     return fn(*args, **kwargs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train.py", line 538, in <module>
#     main() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 794, in main
#     echo(file=sys.stderr)
#   File "/usr/local/lib/python3.8/dist-packages/click/utils.py", line 272, in echo
#     file.write(message)
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/dnnlib/util.py", line 91, in write
#     self.flush()
#   File "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# KeyboardInterrupt
# /usr/lib/python3.8/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 14 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# ^C
