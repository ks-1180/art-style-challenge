# %% [markdown]
# # Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch"
import sys
sys.path.append('.')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch

# %%
# !pip install ninja opensimplex torch==1.7.1 torchvision==0.8.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 145 kB 36.3 MB/s
# ...
#      |████████████████████████████████| 776.8 MB 4.7 kB/s
# ...
#      |████████████████████████████████| 12.8 MB 50.7 MB/s
# ...
#      |████████████████████████████████| 17.1 MB 70 kB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ...

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Dec  3 11:55:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
import os
torch.cuda.is_available()
# Out:
# True

# %%
os.path.exists('/content/drive/MyDrive/repos/art-style-challenge/data/training-runs/')
# Out:
# True

# %%
# %cd "/content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch"
base = "/content/drive/MyDrive/repos/art-style-challenge/data"
dataset = f"{base}/datasets/ghibli_female_256.zip"
outdir = f"{base}/training-runs/"
resume = '/content/drive/MyDrive/data/nvidia-ada-models/ffhq256.pkl'
# !python3 train.py --outdir=$outdir --data=$dataset --gpus=1 --cfg=paper256 --resume=$resume --snap=5 --nobench=True --workers=2
# Out:
# /content/drive/MyDrive/repos/art-style-challenge/extern/stylegan2-ada-pytorch
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 5,
#   "network_snapshot_ticks": 5,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/repos/art-style-challenge/data/datasets/ghibli_female_256.zip",
#     "use_labels": false,
#     "max_size": 2658,
#     "xflip": false,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 2,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
# ...
