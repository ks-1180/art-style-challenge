# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os

library_paths = ['.']


for p in library_paths:
    if p not in sys.path:
        sys.path.append(p)

print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '.']

# %%
movie_name = 'the_wind_rises'
input = f"/content/drive/MyDrive/repos/art-style-challenge/data/{movie_name}/"

for file in os.listdir(input):
  new_name = movie_name + '_' + file
  os.rename(input+file, input+new_name)

# %%
todo = ''
os.path.exists('/content/drive/MyDrive/repos/art-style-challenge/data/pompoki/')
# Out:
# True

# %%
# !cp /content/drive/MyDrive/repos/art-style-challenge/data/earthsea/*.jpg /content/drive/MyDrive/repos/art-style-challenge/data/faces/
