# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd "/content/drive/MyDrive"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
import sys
import os

library_paths = [f'repos/{p}' for p in os.listdir('repos')]
library_paths.append('.')

for p in library_paths:
    if p not in sys.path:
        sys.path.append(p)
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', 'repos/ninja-linux.zip.1', 'repos/restyle-encoder', 'repos/stylegan2-ada-pytorch', 'repos/stylegan2-pytorch', 'repos/util', 'repos/art-style-challenge', 'repos/git.ipynb', '.']

# %%
os.path.exists('/content/drive/MyDrive/repos/art-style-challenge/data/ghibli/ghibli_female')
# Out:
# True

# %%
# %cd "/content/drive/MyDrive/repos/stylegan2-ada-pytorch"
base = "/content/drive/MyDrive/repos/art-style-challenge/data"
data_name = "ghibli_female"
source = f"{base}/ghibli/{data_name}"
res = 256
dest = f"{base}/datasets/{data_name}_{res}.zip"

# !python dataset_tool.py --source=$source --dest=$dest --width=$res --height=$res
# Out:
# /content/drive/MyDrive/repos/stylegan2-ada-pytorch
# 100% 2658/2658 [00:59<00:00, 45.00it/s]

# %% [markdown]
# Note: all files have to be the same format: e.g. jpeg
